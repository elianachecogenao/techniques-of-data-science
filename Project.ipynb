# %%
#Importing libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
#Importing dataframe

df = pd.read_csv("time.csv.gz")
df1 = df[["YEAR","AGE","SEX","CIVSTAT","EDUC","ETHNIC","HISP","DISAB","HHTYPE","NADULT","UNDER5","EMPSTAT","INCOMEQT","EMPSP","ACT_CHCARE","ACT_CIVIC","ACT_EDUCA","ACT_INHOME","ACT_MEDIA","ACT_MISSING","ACT_OUTHOME","ACT_PCARE","ACT_PHYSICAL","ACT_TRAVEL","ACT_UNDOM","ACT_WORK"]]
df1
# Out:
#        YEAR  AGE  SEX  CIVSTAT  EDUC  ETHNIC  HISP  DISAB  HHTYPE  NADULT  \
# 0      2003   36    2        1     5       1     0      0       1       2
# 1      2003   81    2        3     1       1     0      0       7       1
# 2      2003   40    2        2     5       4     0      0       3       1
# 3      2003   32    1        1     4       1     1      0       1       2
# 4      2003   52    2        1     5       1     0      0       2       3
# ...     ...  ...  ...      ...   ...     ...   ...    ...     ...     ...
# 30308  2018   69    2        1     3       1     0      0       2       3
# 30309  2018   32    1        4     5       1     1      0       5       3
# 30310  2018   17    1        2     2       3     0      0       8       4
# 30311  2018   58    2        4     6       1     0      0       7       1
# 30312  2018   72    2        2     5       1     0      0       7       1
#
#        UNDER5  EMPSTAT  INCOMEQT  EMPSP  ACT_CHCARE  ACT_CIVIC  ACT_EDUCA  \
# 0           1        2         3      1          23         12          0
# 1           0        3         1     -7           0        180          0
# 2           0        1        -8     -7          15          0        120
# 3           2        2         2      4         685          0          0
# 4           0        2         4      2           0          0          0
# ...       ...      ...       ...    ...         ...        ...        ...
# 30308       0        3         3      4           0         60          0
# 30309       0        1         3     -7           0          0          0
# 30310       0        3         4     -7           0         30          0
# 30311       0        3         3     -7           0        625          0
# 30312       0        3         3     -7           0          0          0
#
#        ACT_INHOME  ACT_MEDIA  ACT_MISSING  ACT_OUTHOME  ACT_PCARE  \
# 0             155        111            0            0        582
# 1              35        235            0          115        555
# 2             360          0            0            0        705
# 3               0        165            0            0        450
# 4             178          0            0          290        450
# ...           ...        ...          ...          ...        ...
# 30308         120        245            0            0        634
# 30309          40         65           40            0        590
# 30310         135        180            0           30        895
# 30311           0         30            0            0        665
# 30312         300        180            0            0        705
#
#        ACT_PHYSICAL  ACT_TRAVEL  ACT_UNDOM  ACT_WORK
# 0                 0         118         79       360
# 1                55          75        190         0
# 2                 0         240          0         0
# 3                80          40         20         0
# 4               180          92        250         0
# ...             ...         ...        ...       ...
# 30308            77           0        304         0
# 30309             0         165         70       470
# 30310             0         125         45         0
# 30311             0           0        120         0
# 30312             0           0        255         0
#
# [30313 rows x 26 columns]

# %%
def is_missing(x):
    if x != 0:
        return False;
    else:
        return True;

missing_filter = df1["ACT_MISSING"].apply(is_missing)
#missing_filter

# %%
df2 = df1[missing_filter]
time = df2[["YEAR","AGE","SEX","CIVSTAT","EDUC","ETHNIC","HISP","DISAB","HHTYPE","NADULT","UNDER5","EMPSTAT","INCOMEQT","ACT_CHCARE","ACT_CIVIC","ACT_EDUCA","ACT_INHOME","ACT_MEDIA","ACT_OUTHOME","ACT_PCARE","ACT_PHYSICAL","ACT_TRAVEL","ACT_UNDOM","ACT_WORK"]]
time
# Out:
#        YEAR  AGE  SEX  CIVSTAT  EDUC  ETHNIC  HISP  DISAB  HHTYPE  NADULT  \
# 0      2003   36    2        1     5       1     0      0       1       2
# 1      2003   81    2        3     1       1     0      0       7       1
# 2      2003   40    2        2     5       4     0      0       3       1
# 3      2003   32    1        1     4       1     1      0       1       2
# 4      2003   52    2        1     5       1     0      0       2       3
# ...     ...  ...  ...      ...   ...     ...   ...    ...     ...     ...
# 30306  2018   26    1        4     4       1     0      0       5       3
# 30308  2018   69    2        1     3       1     0      0       2       3
# 30310  2018   17    1        2     2       3     0      0       8       4
# 30311  2018   58    2        4     6       1     0      0       7       1
# 30312  2018   72    2        2     5       1     0      0       7       1
#
#        UNDER5  EMPSTAT  INCOMEQT  ACT_CHCARE  ACT_CIVIC  ACT_EDUCA  \
# 0           1        2         3          23         12          0
# 1           0        3         1           0        180          0
# 2           0        1        -8          15          0        120
# 3           2        2         2         685          0          0
# 4           0        2         4           0          0          0
# ...       ...      ...       ...         ...        ...        ...
# 30306       0        3         2           0          0          0
# 30308       0        3         3           0         60          0
# 30310       0        3         4           0         30          0
# 30311       0        3         3           0        625          0
# 30312       0        3         3           0          0          0
#
#        ACT_INHOME  ACT_MEDIA  ACT_OUTHOME  ACT_PCARE  ACT_PHYSICAL  \
# 0             155        111            0        582             0
# 1              35        235          115        555            55
# 2             360          0            0        705             0
# 3               0        165            0        450            80
# 4             178          0          290        450           180
# ...           ...        ...          ...        ...           ...
# 30306         395        300            0        525            10
# 30308         120        245            0        634            77
# 30310         135        180           30        895             0
# 30311           0         30            0        665             0
# 30312         300        180            0        705             0
#
#        ACT_TRAVEL  ACT_UNDOM  ACT_WORK
# 0             118         79       360
# 1              75        190         0
# 2             240          0         0
# 3              40         20         0
# 4              92        250         0
# ...           ...        ...       ...
# 30306         150         60         0
# 30308           0        304         0
# 30310         125         45         0
# 30311           0        120         0
# 30312           0        255         0
#
# [28157 rows x 24 columns]

# %%
time.describe()
# Out:
#                YEAR           AGE           SEX       CIVSTAT          EDUC  \
# count  28157.000000  28157.000000  28157.000000  28157.000000  28157.000000
# mean    2007.562276     46.768441      1.553788      1.973577      3.889477
# std        6.900831     17.558158      0.497107      1.240797      1.367510
# min     2003.000000     15.000000      1.000000      1.000000      1.000000
# 25%     2003.000000     33.000000      1.000000      1.000000      3.000000
# 50%     2003.000000     45.000000      2.000000      1.000000      4.000000
# 75%     2018.000000     60.000000      2.000000      3.000000      5.000000
# max     2018.000000     81.000000      2.000000      4.000000      6.000000
#
#              ETHNIC          HISP         DISAB        HHTYPE        NADULT  \
# count  28157.000000  28157.000000  28157.000000  28157.000000  28157.000000
# mean       1.255354      0.121107      0.044678      3.341478      1.926519
# std        0.628784      0.326257      0.206600      2.511274      0.796822
# min        1.000000      0.000000      0.000000      1.000000      1.000000
# 25%        1.000000      0.000000      0.000000      1.000000      1.000000
# 50%        1.000000      0.000000      0.000000      2.000000      2.000000
# 75%        1.000000      0.000000      0.000000      6.000000      2.000000
# max        5.000000      1.000000      1.000000      8.000000      9.000000
#
#              UNDER5       EMPSTAT      INCOMEQT    ACT_CHCARE     ACT_CIVIC  \
# count  28157.000000  28157.000000  28157.000000  28157.000000  28157.000000
# mean       0.206307      1.846433      1.671911     29.570622     35.309799
# std        0.516752      0.918971      3.077024     77.718169     88.722517
# min        0.000000      1.000000     -8.000000      0.000000      0.000000
# 25%        0.000000      1.000000      1.000000      0.000000      0.000000
# 50%        0.000000      1.000000      2.000000      0.000000      0.000000
# 75%        0.000000      3.000000      3.000000      1.000000     15.000000
# max        5.000000      3.000000      4.000000   1151.000000   1280.000000
#
#           ACT_EDUCA    ACT_INHOME     ACT_MEDIA   ACT_OUTHOME     ACT_PCARE  \
# count  28157.000000  28157.000000  28157.000000  28157.000000  28157.000000
# mean      15.748659     76.355791    213.861384     32.518344    628.431864
# std       80.375723    123.262234    192.754210     76.803970    148.291265
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000     61.000000      0.000000    540.000000
# 50%        0.000000     20.000000    170.000000      0.000000    619.000000
# 75%        0.000000    110.000000    307.000000     30.000000    705.000000
# max     1288.000000   1370.000000   1410.000000    870.000000   1440.000000
#
#        ACT_PHYSICAL    ACT_TRAVEL    ACT_UNDOM      ACT_WORK
# count  28157.000000  28157.000000  28157.00000  28157.000000
# mean      36.597969     75.382321    132.31090    163.912349
# std       82.405942     81.995183    144.25484    243.491102
# min        0.000000      0.000000      0.00000      0.000000
# 25%        0.000000     21.000000     15.00000      0.000000
# 50%        0.000000     60.000000     85.00000      0.000000
# 75%       31.000000    101.000000    204.00000    405.000000
# max      899.000000   1170.000000   1280.00000   1420.000000

# %%
#Mapping categorical variables

sex_map = {1:"Male", 2:"Female"}
time["SEX"] = time["SEX"].map(sex_map)

maritalstatus_map = {1:"Married", 2:"Separated or divorced", 3:"Widowed", 4:"Never married"}
time["CIVSTAT"] = time["CIVSTAT"].map(maritalstatus_map)

education_map = {1:"0-8th grade", 2:"9-11th grade", 3: "High school graduate", 4:"Some college", 5:"College graduate", 6:"Post graduate"}
time["EDUC"] = time["EDUC"].map(education_map)

ethnicity_map = {1:"White", 2:"Black", 3:"Asian", 4:"Some other race", 5:"Hispanic"}
time["ETHNIC"] = time["ETHNIC"].map(ethnicity_map)

household_map = {1:"Married with child", 2:"Married with no child", 3:"Female HH with child", 4:"Female HH with no child", 5:"Male HH", 6:"Single male", 7:"Single female", 8:"Other"}
time["HHTYPE"] = time["HHTYPE"].map(household_map)

employment_map = {1:"Full-time", 2:"Part-time", 3:"Not employed"}
time["EMPSTAT"] = time["EMPSTAT"].map(employment_map)

income_map = {1:"Lowest quartile", 2:"Second lowest quartile", 3:"Second highest quartile", 4:"Highest quartile"}
time["INCOMEQT"] = time["INCOMEQT"].map(income_map)

time
# Out:
# /tmp/ipykernel_133/3808543041.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time["SEX"] = time["SEX"].map(sex_map)
# /tmp/ipykernel_133/3808543041.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time["CIVSTAT"] = time["CIVSTAT"].map(maritalstatus_map)
# /tmp/ipykernel_133/3808543041.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time["EDUC"] = time["EDUC"].map(education_map)
# /tmp/ipykernel_133/3808543041.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time["ETHNIC"] = time["ETHNIC"].map(ethnicity_map)
# /tmp/ipykernel_133/3808543041.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time["HHTYPE"] = time["HHTYPE"].map(household_map)
# /tmp/ipykernel_133/3808543041.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time["EMPSTAT"] = time["EMPSTAT"].map(employment_map)
# /tmp/ipykernel_133/3808543041.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time["INCOMEQT"] = time["INCOMEQT"].map(income_map)
#        YEAR  AGE     SEX                CIVSTAT                  EDUC  \
# 0      2003   36  Female                Married      College graduate
# 1      2003   81  Female                Widowed           0-8th grade
# 2      2003   40  Female  Separated or divorced      College graduate
# 3      2003   32    Male                Married          Some college
# 4      2003   52  Female                Married      College graduate
# ...     ...  ...     ...                    ...                   ...
# 30306  2018   26    Male          Never married          Some college
# 30308  2018   69  Female                Married  High school graduate
# 30310  2018   17    Male  Separated or divorced          9-11th grade
# 30311  2018   58  Female          Never married         Post graduate
# 30312  2018   72  Female  Separated or divorced      College graduate
#
#                 ETHNIC  HISP  DISAB                 HHTYPE  NADULT  UNDER5  \
# 0                White     0      0     Married with child       2       1
# 1                White     0      0          Single female       1       0
# 2      Some other race     0      0   Female HH with child       1       0
# 3                White     1      0     Married with child       2       2
# 4                White     0      0  Married with no child       3       0
# ...                ...   ...    ...                    ...     ...     ...
# 30306            White     0      0                Male HH       3       0
# 30308            White     0      0  Married with no child       3       0
# 30310            Asian     0      0                  Other       4       0
# 30311            White     0      0          Single female       1       0
# 30312            White     0      0          Single female       1       0
#
#             EMPSTAT                 INCOMEQT  ACT_CHCARE  ACT_CIVIC  \
# 0         Part-time  Second highest quartile          23         12
# 1      Not employed          Lowest quartile           0        180
# 2         Full-time                      NaN          15          0
# 3         Part-time   Second lowest quartile         685          0
# 4         Part-time         Highest quartile           0          0
# ...             ...                      ...         ...        ...
# 30306  Not employed   Second lowest quartile           0          0
# 30308  Not employed  Second highest quartile           0         60
# 30310  Not employed         Highest quartile           0         30
# 30311  Not employed  Second highest quartile           0        625
# 30312  Not employed  Second highest quartile           0          0
#
#        ACT_EDUCA  ACT_INHOME  ACT_MEDIA  ACT_OUTHOME  ACT_PCARE  ACT_PHYSICAL  \
# 0              0         155        111            0        582             0
# 1              0          35        235          115        555            55
# 2            120         360          0            0        705             0
# 3              0           0        165            0        450            80
# 4              0         178          0          290        450           180
# ...          ...         ...        ...          ...        ...           ...
# 30306          0         395        300            0        525            10
# 30308          0         120        245            0        634            77
# 30310          0         135        180           30        895             0
# 30311          0           0         30            0        665             0
# 30312          0         300        180            0        705             0
#
#        ACT_TRAVEL  ACT_UNDOM  ACT_WORK
# 0             118         79       360
# 1              75        190         0
# 2             240          0         0
# 3              40         20         0
# 4              92        250         0
# ...           ...        ...       ...
# 30306         150         60         0
# 30308           0        304         0
# 30310         125         45         0
# 30311           0        120         0
# 30312           0        255         0
#
# [28157 rows x 24 columns]

# %%
#dropping rows with missing data:

time.drop_duplicates()

missing_rows = time["INCOMEQT"].isna()
time = time[~ missing_rows]

time
# Out:
#        YEAR  AGE     SEX                CIVSTAT                  EDUC ETHNIC  \
# 0      2003   36  Female                Married      College graduate  White
# 1      2003   81  Female                Widowed           0-8th grade  White
# 3      2003   32    Male                Married          Some college  White
# 4      2003   52  Female                Married      College graduate  White
# 5      2003   46  Female                Married      College graduate  White
# ...     ...  ...     ...                    ...                   ...    ...
# 30306  2018   26    Male          Never married          Some college  White
# 30308  2018   69  Female                Married  High school graduate  White
# 30310  2018   17    Male  Separated or divorced          9-11th grade  Asian
# 30311  2018   58  Female          Never married         Post graduate  White
# 30312  2018   72  Female  Separated or divorced      College graduate  White
#
#        HISP  DISAB                 HHTYPE  NADULT  UNDER5       EMPSTAT  \
# 0         0      0     Married with child       2       1     Part-time
# 1         0      0          Single female       1       0  Not employed
# 3         1      0     Married with child       2       2     Part-time
# 4         0      0  Married with no child       3       0     Part-time
# 5         0      0  Married with no child       2       0     Full-time
# ...     ...    ...                    ...     ...     ...           ...
# 30306     0      0                Male HH       3       0  Not employed
# 30308     0      0  Married with no child       3       0  Not employed
# 30310     0      0                  Other       4       0  Not employed
# 30311     0      0          Single female       1       0  Not employed
# 30312     0      0          Single female       1       0  Not employed
#
#                       INCOMEQT  ACT_CHCARE  ACT_CIVIC  ACT_EDUCA  ACT_INHOME  \
# 0      Second highest quartile          23         12          0         155
# 1              Lowest quartile           0        180          0          35
# 3       Second lowest quartile         685          0          0           0
# 4             Highest quartile           0          0          0         178
# 5      Second highest quartile           0         60          0          60
# ...                        ...         ...        ...        ...         ...
# 30306   Second lowest quartile           0          0          0         395
# 30308  Second highest quartile           0         60          0         120
# 30310         Highest quartile           0         30          0         135
# 30311  Second highest quartile           0        625          0           0
# 30312  Second highest quartile           0          0          0         300
#
#        ACT_MEDIA  ACT_OUTHOME  ACT_PCARE  ACT_PHYSICAL  ACT_TRAVEL  ACT_UNDOM  \
# 0            111            0        582             0         118         79
# 1            235          115        555            55          75        190
# 3            165            0        450            80          40         20
# 4              0          290        450           180          92        250
# 5            335           60        490            60          60        255
# ...          ...          ...        ...           ...         ...        ...
# 30306        300            0        525            10         150         60
# 30308        245            0        634            77           0        304
# 30310        180           30        895             0         125         45
# 30311         30            0        665             0           0        120
# 30312        180            0        705             0           0        255
#
#        ACT_WORK
# 0           360
# 1             0
# 3             0
# 4             0
# 5            60
# ...         ...
# 30306         0
# 30308         0
# 30310         0
# 30311         0
# 30312         0
#
# [25863 rows x 24 columns]

# %%
#Resetting index

time = time.reset_index(drop = True)
time
# Out:
#        YEAR  AGE     SEX                CIVSTAT                  EDUC ETHNIC  \
# 0      2003   36  Female                Married      College graduate  White
# 1      2003   81  Female                Widowed           0-8th grade  White
# 2      2003   32    Male                Married          Some college  White
# 3      2003   52  Female                Married      College graduate  White
# 4      2003   46  Female                Married      College graduate  White
# ...     ...  ...     ...                    ...                   ...    ...
# 25858  2018   26    Male          Never married          Some college  White
# 25859  2018   69  Female                Married  High school graduate  White
# 25860  2018   17    Male  Separated or divorced          9-11th grade  Asian
# 25861  2018   58  Female          Never married         Post graduate  White
# 25862  2018   72  Female  Separated or divorced      College graduate  White
#
#        HISP  DISAB                 HHTYPE  NADULT  UNDER5       EMPSTAT  \
# 0         0      0     Married with child       2       1     Part-time
# 1         0      0          Single female       1       0  Not employed
# 2         1      0     Married with child       2       2     Part-time
# 3         0      0  Married with no child       3       0     Part-time
# 4         0      0  Married with no child       2       0     Full-time
# ...     ...    ...                    ...     ...     ...           ...
# 25858     0      0                Male HH       3       0  Not employed
# 25859     0      0  Married with no child       3       0  Not employed
# 25860     0      0                  Other       4       0  Not employed
# 25861     0      0          Single female       1       0  Not employed
# 25862     0      0          Single female       1       0  Not employed
#
#                       INCOMEQT  ACT_CHCARE  ACT_CIVIC  ACT_EDUCA  ACT_INHOME  \
# 0      Second highest quartile          23         12          0         155
# 1              Lowest quartile           0        180          0          35
# 2       Second lowest quartile         685          0          0           0
# 3             Highest quartile           0          0          0         178
# 4      Second highest quartile           0         60          0          60
# ...                        ...         ...        ...        ...         ...
# 25858   Second lowest quartile           0          0          0         395
# 25859  Second highest quartile           0         60          0         120
# 25860         Highest quartile           0         30          0         135
# 25861  Second highest quartile           0        625          0           0
# 25862  Second highest quartile           0          0          0         300
#
#        ACT_MEDIA  ACT_OUTHOME  ACT_PCARE  ACT_PHYSICAL  ACT_TRAVEL  ACT_UNDOM  \
# 0            111            0        582             0         118         79
# 1            235          115        555            55          75        190
# 2            165            0        450            80          40         20
# 3              0          290        450           180          92        250
# 4            335           60        490            60          60        255
# ...          ...          ...        ...           ...         ...        ...
# 25858        300            0        525            10         150         60
# 25859        245            0        634            77           0        304
# 25860        180           30        895             0         125         45
# 25861         30            0        665             0           0        120
# 25862        180            0        705             0           0        255
#
#        ACT_WORK
# 0           360
# 1             0
# 2             0
# 3             0
# 4            60
# ...         ...
# 25858         0
# 25859         0
# 25860         0
# 25861         0
# 25862         0
#
# [25863 rows x 24 columns]

# %%
time.groupby("YEAR").describe(include = ["O"])
# Out:
#         SEX                      CIVSTAT                          EDUC         \
#       count unique     top  freq   count unique      top   freq  count unique
# YEAR
# 2003  17299      2  Female  9636   17299      4  Married  10017  17299      6
# 2018   8564      2  Female  4637    8564      4  Married   4419   8564      6
#
#                                  ETHNIC                      HHTYPE         \
#                        top  freq  count unique    top   freq  count unique
# YEAR
# 2003  High school graduate  4740  17299      5  White  14480  17299      8
# 2018      College graduate  2872   8564      4  White   6799   8564      8
#
#                                EMPSTAT                         INCOMEQT  \
#                      top  freq   count unique        top  freq    count
# YEAR
# 2003  Married with child  6244   17299      3  Full-time  9102    17299
# 2018  Married with child  2242    8564      3  Full-time  4280     8564
#
#
#      unique                      top  freq
# YEAR
# 2003      4  Second highest quartile  5084
# 2018      4   Second lowest quartile  2289

# %%
filter2003 = time["YEAR"]==2003
time2003 = time[filter2003]
time2018 = time[~filter2003]

time2018
# Out:
#        YEAR  AGE     SEX                CIVSTAT                  EDUC ETHNIC  \
# 17299  2018   42    Male  Separated or divorced          Some college  White
# 17300  2018   58    Male  Separated or divorced  High school graduate  White
# 17301  2018   65    Male                Married          9-11th grade  Black
# 17302  2018   66  Female          Never married          Some college  Black
# 17303  2018   55  Female  Separated or divorced          9-11th grade  Black
# ...     ...  ...     ...                    ...                   ...    ...
# 25858  2018   26    Male          Never married          Some college  White
# 25859  2018   69  Female                Married  High school graduate  White
# 25860  2018   17    Male  Separated or divorced          9-11th grade  Asian
# 25861  2018   58  Female          Never married         Post graduate  White
# 25862  2018   72  Female  Separated or divorced      College graduate  White
#
#        HISP  DISAB                 HHTYPE  NADULT  UNDER5       EMPSTAT  \
# 17299     0      0            Single male       1       0  Not employed
# 17300     0      1            Single male       1       0  Not employed
# 17301     0      1  Married with no child       3       0  Not employed
# 17302     0      0          Single female       1       0     Part-time
# 17303     0      0          Single female       1       0     Full-time
# ...     ...    ...                    ...     ...     ...           ...
# 25858     0      0                Male HH       3       0  Not employed
# 25859     0      0  Married with no child       3       0  Not employed
# 25860     0      0                  Other       4       0  Not employed
# 25861     0      0          Single female       1       0  Not employed
# 25862     0      0          Single female       1       0  Not employed
#
#                       INCOMEQT  ACT_CHCARE  ACT_CIVIC  ACT_EDUCA  ACT_INHOME  \
# 17299   Second lowest quartile           0          0          0         208
# 17300          Lowest quartile           0          0          0           0
# 17301  Second highest quartile           0         94          0           0
# 17302          Lowest quartile           0        300          0          45
# 17303  Second highest quartile           0          0          0           0
# ...                        ...         ...        ...        ...         ...
# 25858   Second lowest quartile           0          0          0         395
# 25859  Second highest quartile           0         60          0         120
# 25860         Highest quartile           0         30          0         135
# 25861  Second highest quartile           0        625          0           0
# 25862  Second highest quartile           0          0          0         300
#
#        ACT_MEDIA  ACT_OUTHOME  ACT_PCARE  ACT_PHYSICAL  ACT_TRAVEL  ACT_UNDOM  \
# 17299        465           30        600             0          45         92
# 17300        880            0        490             0           0         70
# 17301        349            0        910             0          51         36
# 17302        110           65        695             0         225          0
# 17303        210            0       1220             0           0         10
# ...          ...          ...        ...           ...         ...        ...
# 25858        300            0        525            10         150         60
# 25859        245            0        634            77           0        304
# 25860        180           30        895             0         125         45
# 25861         30            0        665             0           0        120
# 25862        180            0        705             0           0        255
#
#        ACT_WORK
# 17299         0
# 17300         0
# 17301         0
# 17302         0
# 17303         0
# ...         ...
# 25858         0
# 25859         0
# 25860         0
# 25861         0
# 25862         0
#
# [8564 rows x 24 columns]

# %%
time2003["AGE"].hist(bins=30, color = "palevioletred")
plt.title("Ages of Respondents of AHTUS 2003")
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sex_counts = time2003["SEX"].value_counts()
sex_counts.plot(kind = "bar", color = "palevioletred")
plt.title("Sex of Respondents of AHTUS 2003")
plt.xlabel("Sex")
plt.ylabel("Frequency")
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
employment_counts = time2003["EMPSTAT"].value_counts()
employment_counts.plot(kind = "bar", color = "palevioletred")
plt.title("Employment Status of Respondents of AHTUS 2003")
plt.xlabel("Employment Status")
plt.ylabel("Frequency")
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Full-time'),
#   Text(1, 0, 'Not employed'),
#   Text(2, 0, 'Part-time')])

# %%
education_counts = time2003["EDUC"].value_counts()
education_counts.plot(kind = "bar", color = "palevioletred")
plt.title("Educational Attainment of Respondents of AHTUS 2003")
plt.xlabel("Educational Attainment")
plt.ylabel("Frequency")
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'High school graduate'),
#   Text(1, 0, 'College graduate'),
#   Text(2, 0, 'Some college'),
#   Text(3, 0, '9-11th grade'),
#   Text(4, 0, 'Post graduate'),
#   Text(5, 0, '0-8th grade')])

# %%
time2003["DOM_CHCARE"] = time2003["ACT_UNDOM"] + time2003["ACT_CHCARE"]
palette1 = {"mediumvioletred", "pink"}
a = sns.relplot( x = "DOM_CHCARE", y = "ACT_WORK", hue = "SEX", palette = palette1, data = time2003)
a.fig.set_size_inches(12,10)
plt.title("Time Spent on Childcare and Unpaid Domestic Labor vs Time Spent on Paid Work by Sex")
plt.xlabel("Time Spent on Childcare and Unpaid Domestic Labor (Minutes)")
plt.ylabel("Time Spent on Paid Work (Minutes)")
# Out:
# /tmp/ipykernel_133/681308529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time2003["DOM_CHCARE"] = time2003["ACT_UNDOM"] + time2003["ACT_CHCARE"]
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(44.995444444444445, 0.5, 'Time Spent on Paid Work (Minutes)')

# %%
palette2 = {"pink","mediumvioletred","purple", "palevioletred"}

sns.catplot(x = "INCOMEQT", y = "ACT_WORK", kind = "box", palette = palette2, data = time2003)
plt.title("Time Spent on Paid Work by Income Quartile")
plt.xlabel("Income Quartile")
plt.ylabel("Time Spent on Paid Work (Minutes)")
plt.xticks(rotation=30)
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Second highest quartile'),
#   Text(1, 0, 'Lowest quartile'),
#   Text(2, 0, 'Second lowest quartile'),
#   Text(3, 0, 'Highest quartile')])

# %%
time2018["AGE"].hist(bins=30, color = "palevioletred")
plt.title("Ages of Respondents of AHTUS 2018")
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sex_counts2018 = time2018["SEX"].value_counts()
sex_counts2018.plot(kind = "bar", color = "palevioletred")
plt.title("Sex of Respondents of AHTUS 2018")
plt.xlabel("Sex")
plt.ylabel("Frequency")
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
employment_counts2018 = time2018["EMPSTAT"].value_counts()
employment_counts2018.plot(kind = "bar", color = "palevioletred")
plt.title("Employment Status of Respondents of AHTUS 2018")
plt.xlabel("Employment Status")
plt.ylabel("Frequency")
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Full-time'),
#   Text(1, 0, 'Not employed'),
#   Text(2, 0, 'Part-time')])

# %%
education_counts2018 = time2018["EDUC"].value_counts()
education_counts2018.plot(kind = "bar", color = "palevioletred")
plt.title("Educational Attainment of Respondents of AHTUS 2018")
plt.xlabel("Educational Attainment")
plt.ylabel("Frequency")
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'College graduate'),
#   Text(1, 0, 'High school graduate'),
#   Text(2, 0, 'Some college'),
#   Text(3, 0, 'Post graduate'),
#   Text(4, 0, '9-11th grade'),
#   Text(5, 0, '0-8th grade')])

# %%
time2018["DOM_CHCARE"] = time2018["ACT_UNDOM"] + time2018["ACT_CHCARE"]
palette1 = {"mediumvioletred", "pink"}
a = sns.relplot( x = "DOM_CHCARE", y = "ACT_WORK", hue = "SEX", palette = palette1, data = time2018)
a.fig.set_size_inches(12,10)
plt.title("Time Spent on Childcare and Unpaid Domestic Labor vs Time Spent on Paid Work by Sex")
plt.xlabel("Time Spent on Childcare and Unpaid Domestic Labor (Minutes)")
plt.ylabel("Time Spent on Paid Work (Minutes)")
# Out:
# /tmp/ipykernel_133/3300482592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time2018["DOM_CHCARE"] = time2018["ACT_UNDOM"] + time2018["ACT_CHCARE"]
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(44.995444444444445, 0.5, 'Time Spent on Paid Work (Minutes)')

# %%
palette2 = {"pink","mediumvioletred","purple", "palevioletred"}

sns.catplot(x = "INCOMEQT", y = "ACT_WORK", kind = "box", palette = palette2, data = time2018)
plt.title("Time Spent on Paid Work by Income Quartile")
plt.xlabel("Income Quartile")
plt.ylabel("Time Spent on Paid Work (Minutes)")
plt.xticks(rotation=30)
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Second lowest quartile'),
#   Text(1, 0, 'Lowest quartile'),
#   Text(2, 0, 'Second highest quartile'),
#   Text(3, 0, 'Highest quartile')])

# %%
sns.catplot(x = "YEAR", y = "ACT_MEDIA", kind = "box", palette = palette1, data = time)
plt.title("Time Spent on Media by Year")
plt.xlabel("Year")
plt.ylabel("Time Spent on Media (Minutes)")
plt.xticks(rotation=0)
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (array([0, 1]), [Text(0, 0, '2003'), Text(1, 0, '2018')])
